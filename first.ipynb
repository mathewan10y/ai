# %%
#begin
#alt+shift+down to duplicate line
''' numpy--For handling heavy mathematical calculations (matrices),arrays.
Creating arrays: np.array(), np.zeros(), np.ones(), np.arange()
Array operations: element-wise addition, subtraction, multiplication, division
Statistical functions: np.mean(), np.median(), np.std(), np.sum()
Reshaping arrays: arr.reshape(), arr.flatten()'''

'''pandas-- for handling data in tabular form (dataframes).
Loading data: pd.read_csv()
Inspecting data: df.head(), df.info(), df.describe(), df.columns
Selecting data: df['column_name'], df.iloc[] (by position), df.loc[] (by label).
Basic cleaning: df.dropna() (drop empty rows), df.fillna()'''

'''matplotlib-- for plotting graphs and visualizations.(bar,pie,histogram,boxplot,scatter)
Plotting: plt.plot(x, y), plt.scatter(x, y), plt.bar(x, height)
Customizing: plt.title(), plt.xlabel(), plt.ylabel(), plt.legend()
Displaying: plt.show()
'''

print("hello")
# Out:
# hello

# %%
import numpy as np
# import pandas as pd
# from matplotlib import pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import numpy as np
#       2 # import pandas as pd
#       3 # from matplotlib import pyplot as plt
#
# ModuleNotFoundError: No module named 'numpy'

# %%
'''
mean-- the average of a set of numbers. It is calculated by adding all the numbers together and then dividing by the count of numbers. The mean provides a central value for the data set.

median-- the middle value in a sorted list of numbers. If the list has an odd number of values, the median is the middle one. If it has an even number of values, the median is the average of the two middle values. The median is useful for understanding the center of a data set, especially when there are outliers(weird data) that can skew the mean.

variance-- a measure of how spread out a set of data is. It quantifies the average squared deviation of each data point from the mean. A high variance indicates that the data points are more spread out, while a low variance indicates that they are closer to the mean.

standard deviation-- the square root of the variance. It provides a measure of the average distance of each data point from the mean in the same units as the original data. Standard deviation is often used to understand the dispersion of data points around the mean.
If the average height is 180cm and the Std Dev is 10cm, you immediately know that most people(68%) are between 170cm and 190cm.'''

# %%
''' we can compare numerical values to  non numerical values. while comparing numerical values, it may be nescessary to standardize or normalize the data to ensure fair comparisons. Standardization involves transforming the data to have a mean of zero and a standard deviation of one, while normalization scales the data to a specific range, typically between 0 and 1. These techniques help in mitigating the effects of different scales and units, allowing for more meaningful comparisons between numerical values.

normaliation can be done using minmax scaling.
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
data_normalized = scaler.fit_transform(data)'''
